# %% [markdown]
# <a href="https://colab.research.google.com/github/kris743/python-ml/blob/main/Copy_of_Pandas_Exercise_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# use AUTOMOBILE DATASET

# %% [markdown]
# # New Section

# %% [markdown]
# Question 1: From given data set print first and last five rows

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Display the first 5 rows of the DataFrame to get an overview of the data
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Display the last 5 rows of the DataFrame
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# Question 2: Clean data and update the CSV file
# Replace all column values which contain ‘?’ and n.a with NaN.

# %%
# Read the CSV file again, this time specifying '?' and 'n.a' as NaN values
# This cleans the data by replacing these placeholders with actual NaN (Not a Number) values
# for the specified columns: 'price', 'stroke', 'horsepower', 'peak-rpm', 'average-mileage'
df = pd.read_csv("/content/Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})

# Print the entire DataFrame after cleaning to see the updated values
print (df)

# Save the cleaned DataFrame back to a CSV file.
# Note: The original path 'D:\Python\Articles\pandas\automobile-dataset\Automobile_data.csv'
# might be specific to a local machine. For Colab, it usually means saving to the current directory or a specific '/content/' path.
# If this path doesn't exist or is not writable, this line might cause an error in a Colab environment.
df.to_csv("D:\Python\Articles\pandas\automobile-dataset\Automobile_data.csv")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# Question 3: Find the most expensive car company name
# Print most expensive car’s company name and price.

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Filter the DataFrame to find the row(s) where the 'price' is equal to the maximum price in the 'price' column.
# This effectively finds the most expensive car(s).
# It then selects only the 'company' and 'price' columns for these rows.
df = df [['company','price']][df.price==df['price'].max()]

# Display the resulting DataFrame which contains the company and price of the most expensive car(s)
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %%
# Question 4: Print All Toyota Cars details
# This cell is currently a comment, indicating the task for this section.
# To print all Toyota car details, you would typically filter the DataFrame for 'company' == 'toyota'.
# Example of how to get Toyota cars:
# toyota_cars = df[df['company'] == 'toyota']
# display(toyota_cars)

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Group the DataFrame by the 'company' column. This creates a GroupBy object.
# This object can then be used to perform operations on each group (each company).
car_Manufacturers = df.groupby('company')

# Get a specific group from the GroupBy object, in this case, the group for 'toyota' cars.
toyotaDf = car_Manufacturers.get_group('toyota')

# Display the DataFrame containing only Toyota car details
toyotaDf
# Out:
#     index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average-mileage    price
# 48          62               35   5348.0
# 49          62               31   6338.0
# 50          62               31   6488.0
# 51          62               31   6918.0
# 52          62               27   7898.0
# 53          62               27   8778.0
# 54         156               19  15750.0

# %%
# Question 5: Count total cars per company
# This cell is currently a comment, indicating the task for this section.
# To count total cars per company, you would typically use value_counts() on the 'company' column
# or group by 'company' and count. See the following cell for an example.

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Count the occurrences of each unique value in the 'company' column.
# This effectively counts the number of cars for each manufacturing company.
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# mercedes-benz    4
# audi             4
# volkswagen       4
# mitsubishi       4
# chevrolet        3
# jaguar           3
# isuzu            3
# honda            3
# porsche          3
# alfa-romero      3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %%
# Question 6: Find each company’s Higesht price car
# This cell is currently a comment, indicating the task for this section.
# To find the highest price car for each company, you would group by 'company' and then find the max 'price'.

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Group the DataFrame by the 'company' column.
car_Manufacturers = df.groupby('company')

# Select the 'price' column from the grouped object and find the maximum price for each company.
priceDf = car_Manufacturers['price'].max()

# Display the Series containing the highest price for each car manufacturer
priceDf
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
# Question 7: Find the average mileage of each car making company
# This cell is currently a comment, indicating the task for this section.
# To find the average mileage, you would group by 'company' and calculate the mean of 'average-mileage'.

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
df = pd.read_csv("/content/Automobile_data.csv")

# Group the DataFrame by the 'company' column.
car_Manufacturers = df.groupby('company')

# Select the 'average-mileage' column from the grouped object and calculate the mean for each company.
mileageDf = car_Manufacturers['average-mileage'].mean()

# Display the Series containing the average mileage for each car manufacturer
mileageDf
# Out:
# company
# alfa-romero      20.333333
# audi             20.000000
# bmw              19.000000
# chevrolet        41.000000
# dodge            31.000000
# honda            26.333333
# isuzu            33.333333
# jaguar           14.333333
# mazda            28.000000
# mercedes-benz    18.000000
# mitsubishi       29.500000
# nissan           31.400000
# porsche          17.000000
# toyota           28.714286
# volkswagen       31.750000
# volvo            23.000000
# Name: average-mileage, dtype: float64

# %%
# Question 8: Sort all cars by Price column
# This cell is currently a comment, indicating the task for this section.
# To sort all cars, you would use the sort_values() method on the DataFrame based on the 'price' column.

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Read the CSV file 'Automobile_data.csv' into a pandas DataFrame
carsDf = pd.read_csv("/content/Automobile_data.csv")

# Sort the DataFrame by 'price' in descending order. If prices are equal, then sort by 'horsepower' in descending order.
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)

# Display the first 5 rows of the sorted DataFrame to show the most expensive cars
carsDf.head(5)
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 35     47  mercedes-benz      hardtop       112.0   199.2        ohcv
# 11     14            bmw        sedan       103.5   193.8         ohc
# 34     46  mercedes-benz        sedan       120.9   208.1        ohcv
# 46     62        porsche  convertible        89.5   168.9        ohcf
# 12     15            bmw        sedan       110.0   197.0         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 35            eight         184               14  45400.0
# 11              six         182               16  41315.0
# 34            eight         184               14  40960.0
# 46              six         207               17  37028.0
# 12              six         182               15  36880.0

# %%
##Question 9: Concatenate two data frames using following conditions

    ##Create two data frames using following two Dicts, Concatenate those two data frame and create a key for each data frame.

# Define a dictionary for German car data
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}

# Define a dictionary for Japanese car data
japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# The next steps would involve creating DataFrames from these dictionaries and concatenating them.
# For example:
# df_german = pd.DataFrame(GermanCars)
# df_japanese = pd.DataFrame(japaneseCars)
# combined_df = pd.concat([df_german, df_japanese], keys=['German', 'Japanese'])

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Define a dictionary for German car data
GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}

# Create a pandas DataFrame from the GermanCars dictionary
carsDf1 = pd.DataFrame.from_dict(GermanCars)

# Display the created DataFrame
# carsDf1 # (This line was commented out in the original, adding it would show the DataFrame)

# %%
##Question 10: Merge two data frames using following condition
    ##Create two data frames using following two Dicts, Merge two data frames, and append second data frame as a new column to first data frame.

# Define a dictionary for car prices
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}

# Define a dictionary for car horsepower
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# The next steps would involve creating DataFrames from these dictionaries and merging them.
# For example:
# carPriceDf = pd.DataFrame.from_dict(Car_Price)
# carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)
# merged_df = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")

# %%
# Import the pandas library for data manipulation
import pandas as pd

# Define a dictionary for car prices
Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}

# Create a pandas DataFrame from the Car_Price dictionary
carPriceDf = pd.DataFrame.from_dict(Car_Price)

# Define a dictionary for car horsepower
car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}

# Create a pandas DataFrame from the car_Horsepower dictionary
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)

# Merge the two DataFrames (carPriceDf and carsHorsepowerDf) based on the common 'Company' column.
# This appends the 'horsepower' column to the carPriceDf, matching companies.
carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")

# Display the merged DataFrame
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
